# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_table('./gi-archestra_2005.csv', sep='\n', header=None, delimiter=";")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.

# %%
data.head()
# Out:
#                            0                       1
# 0                       Time  Free disk space on C:\
# 1  2019-05-20T08:07:50+02:00              4759314432
# 2  2019-05-20T08:08:50+02:00              4759314432
# 3  2019-05-20T08:09:50+02:00              4759314432
# 4  2019-05-20T08:10:50+02:00              4759314432

# %%
data.columns = ['Time', 'FD']

# %%
data.head()
data.shape
# Out:
# (175, 2)

# %%
data = data[1:]

# %%
data.shape
# Out:
# (174, 2)

# %%
plt.figure(figsize=(15,7))
plt.plot(data.FD)
plt.grid(True)
plt.show()
